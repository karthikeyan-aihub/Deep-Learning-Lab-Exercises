# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
titanic_file_path = tf.keras.utils.get_file("train.csv", 
                                            "https://storage.googleapis.com/tf-datasets/titanic/train.csv")
df = pd.read_csv(titanic_file_path)
df.head()
# Out:
#    survived     sex   age  n_siblings_spouses  parch     fare  class     deck  \
# 0         0    male  22.0                   1      0   7.2500  Third  unknown
# 1         1  female  38.0                   1      0  71.2833  First        C
# 2         1  female  26.0                   0      0   7.9250  Third  unknown
# 3         1  female  35.0                   1      0  53.1000  First        C
# 4         0    male  28.0                   0      0   8.4583  Third  unknown
#
#    embark_town alone
# 0  Southampton     n
# 1    Cherbourg     n
# 2  Southampton     y
# 3  Southampton     n
# 4   Queenstown     y

# %%
df.rename(columns ={"survived":"target"},inplace=True)
np.random.seed(5)
train, val, test = np.split(df.sample(frac=1),[int(0.8*len(df)),
int(0.9*len(df))])
train
# Out:
# C:\Users\karth\AppData\Roaming\Python\Python312\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
#      target     sex   age  n_siblings_spouses  parch      fare   class  \
# 445       0    male  57.0                   0      0   12.3500  Second
# 230       1  female  31.0                   0      2  164.8667   First
# 289       1    male  39.0                   0      0    7.9250   Third
# 622       0    male  28.0                   0      0   10.5000  Second
# 361       0  female  37.0                   0      0    9.5875   Third
# ..      ...     ...   ...                 ...    ...       ...     ...
# 572       0    male  35.0                   0      0   10.5000  Second
# 54        0    male  26.0                   2      0    8.6625   Third
# 19        0    male  28.0                   0      0    7.2250   Third
# 609       1  female  27.0                   1      0   13.8583  Second
# 178       0    male  22.0                   0      0    7.1250   Third
#
#         deck  embark_town alone
# 445  unknown   Queenstown     y
# 230        C  Southampton     n
# 289  unknown  Southampton     y
# 622  unknown  Southampton     y
# 361  unknown  Southampton     y
# ..       ...          ...   ...
# 572  unknown  Southampton     y
# 54   unknown  Southampton     n
# 19   unknown    Cherbourg     y
# 609  unknown    Cherbourg     n
# 178  unknown  Southampton     y
#
# [501 rows x 10 columns]

# %%
def df_to_dataset(dataframe, shuffle=True, batch_size=32):
    df = dataframe.copy()
    labels = df.pop('target')
    df = {key: value.values[:, tf.newaxis] for key, value in dataframe.items()}
    ds = tf.data.Dataset.from_tensor_slices((dict(df), labels))
    
    if shuffle:
        ds = ds.shuffle(buffer_size=len(dataframe))
    
    ds = ds.batch(batch_size)
    ds = ds.prefetch(batch_size)
    return ds

batch_size = 10
train_ds = df_to_dataset(train, batch_size=batch_size)
val_ds = df_to_dataset(val, batch_size=batch_size)
test_ds = df_to_dataset(test, batch_size=batch_size)

# %%
def get_normalization_layer(name, dataset):
   
    normalizer = tf.keras.layers.Normalization(axis=None)
    
   
    feature_ds = dataset.map(lambda x, y: x[name])
    
    
    normalizer.adapt(feature_ds)
    
    return normalizer


def get_category_encoding_layer(name, dataset, dtype, max_tokens=None):
    
    if dtype == 'string':
        index = tf.keras.layers.StringLookup(max_tokens=max_tokens)
    
    else:
        index = tf.keras.layers.IntegerLookup(max_tokens=max_tokens)

    feature_ds = dataset.map(lambda x, y: x[name])
    
 
    index.adapt(feature_ds)
    
    
    encoder = tf.keras.layers.CategoryEncoding(num_tokens=index.vocabulary_size())
    
   
    return lambda feature: encoder(index(feature))


numerical_cols = ["age", "fare"]
numerical_categorical_cols = ["n_siblings_spouses", "parch"]
categorical_cols = ["sex", "class", "deck", "embark_town", "alone"]

all_inputs = []
encoded_features = []


for header in numerical_cols:
    numeric_col = tf.keras.Input(shape=(1,), name=header)
    normalization_layer = get_normalization_layer(header, train_ds)  # Normalization
    encoded_numeric_col = normalization_layer(numeric_col)
    all_inputs.append(numeric_col)
    encoded_features.append(encoded_numeric_col)


for header in numerical_categorical_cols:
    categorical_col = tf.keras.Input(shape=(1,), name=header, dtype='int64')
    encoding_layer = get_category_encoding_layer(name=header, dataset=train_ds, dtype='int64')  # Encoding
    encoded_categorical_col = encoding_layer(categorical_col)
    all_inputs.append(categorical_col)
    encoded_features.append(encoded_categorical_col)


for header in categorical_cols:
    categorical_col = tf.keras.Input(shape=(1,), name=header, dtype='string')
    encoding_layer = get_category_encoding_layer(name=header, dataset=train_ds, dtype='string', max_tokens=5)  # Encoding
    encoded_categorical_col = encoding_layer(categorical_col)
    all_inputs.append(categorical_col)
    encoded_features.append(encoded_categorical_col)

# %%
x = tf.keras.layers.concatenate(encoded_features)
x = tf.keras.layers.Dense(32, activation="relu")(x)
x = tf.keras.layers.Dense(8, activation="relu")(x)
x = tf.keras.layers.Dense(4, activation="relu")(x)
x = tf.keras.layers.Dense(2, activation="relu")(x)
outputs = tf.keras.layers.Dense(1, activation="sigmoid")(x)

model = tf.keras.Model(all_inputs, outputs)

model.compile(
    optimizer='adam',
    loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
    metrics=["accuracy"]
)

tf.keras.utils.plot_model(model)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
history =model.fit(train_ds,validation_data=val_ds,epochs=50)
# Out:
# Epoch 1/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5912 - loss: 0.6492 - val_accuracy: 0.5714 - val_loss: 0.6399
# Epoch 2/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6071 - loss: 0.6032 - val_accuracy: 0.6032 - val_loss: 0.6068
# Epoch 3/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6846 - loss: 0.5715 - val_accuracy: 0.7143 - val_loss: 0.5707
# Epoch 4/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7680 - loss: 0.5047 - val_accuracy: 0.7619 - val_loss: 0.5391
# Epoch 5/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7979 - loss: 0.5082 - val_accuracy: 0.8095 - val_loss: 0.5245
# Epoch 6/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8135 - loss: 0.4948 - val_accuracy: 0.8571 - val_loss: 0.5183
# Epoch 7/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8181 - loss: 0.4813 - val_accuracy: 0.8571 - val_loss: 0.5165
# Epoch 8/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8422 - loss: 0.4692 - val_accuracy: 0.8571 - val_loss: 0.5061
# Epoch 9/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8338 - loss: 0.4735 - val_accuracy: 0.8571 - val_loss: 0.5024
# Epoch 10/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8520 - loss: 0.4658 - val_accuracy: 0.8413 - val_loss: 0.4995
# Epoch 11/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8511 - loss: 0.4461 - val_accuracy: 0.8730 - val_loss: 0.4933
# Epoch 12/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8217 - loss: 0.4721 - val_accuracy: 0.8413 - val_loss: 0.4906
# Epoch 13/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8526 - loss: 0.4393 - val_accuracy: 0.8413 - val_loss: 0.4873
# Epoch 14/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8533 - loss: 0.4279 - val_accuracy: 0.8571 - val_loss: 0.4805
# Epoch 15/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8374 - loss: 0.4459 - val_accuracy: 0.8730 - val_loss: 0.4775
# Epoch 16/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8402 - loss: 0.4438 - val_accuracy: 0.8413 - val_loss: 0.4769
# Epoch 17/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8674 - loss: 0.4135 - val_accuracy: 0.8413 - val_loss: 0.4720
# Epoch 18/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8493 - loss: 0.4316 - val_accuracy: 0.8571 - val_loss: 0.4640
# Epoch 19/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8602 - loss: 0.4366 - val_accuracy: 0.8413 - val_loss: 0.4643
# Epoch 20/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8553 - loss: 0.4223 - val_accuracy: 0.8413 - val_loss: 0.4639
# Epoch 21/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8386 - loss: 0.4451 - val_accuracy: 0.8413 - val_loss: 0.4595
# Epoch 22/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8691 - loss: 0.4037 - val_accuracy: 0.8413 - val_loss: 0.4612
# Epoch 23/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8821 - loss: 0.3801 - val_accuracy: 0.8413 - val_loss: 0.4657
# Epoch 24/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8585 - loss: 0.4020 - val_accuracy: 0.8571 - val_loss: 0.4603
# Epoch 25/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8413 - loss: 0.4280 - val_accuracy: 0.8730 - val_loss: 0.4627
# Epoch 26/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8856 - loss: 0.3767 - val_accuracy: 0.8413 - val_loss: 0.4555
# Epoch 27/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8357 - loss: 0.4126 - val_accuracy: 0.8730 - val_loss: 0.4805
# Epoch 28/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8753 - loss: 0.3814 - val_accuracy: 0.8730 - val_loss: 0.4421
# Epoch 29/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8799 - loss: 0.3805 - val_accuracy: 0.8571 - val_loss: 0.4502
# Epoch 30/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8486 - loss: 0.3956 - val_accuracy: 0.8730 - val_loss: 0.4399
# Epoch 31/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.3778 - val_accuracy: 0.8571 - val_loss: 0.4423
# Epoch 32/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8552 - loss: 0.3862 - val_accuracy: 0.8730 - val_loss: 0.4443
# Epoch 33/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8819 - loss: 0.3693 - val_accuracy: 0.8571 - val_loss: 0.4378
# Epoch 34/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8872 - loss: 0.3544 - val_accuracy: 0.8571 - val_loss: 0.4441
# Epoch 35/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8784 - loss: 0.3510 - val_accuracy: 0.8571 - val_loss: 0.4290
# Epoch 36/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8487 - loss: 0.3825 - val_accuracy: 0.8571 - val_loss: 0.4405
# Epoch 37/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8802 - loss: 0.3656 - val_accuracy: 0.8571 - val_loss: 0.4385
# Epoch 38/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8724 - loss: 0.3720 - val_accuracy: 0.8730 - val_loss: 0.4378
# Epoch 39/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8763 - loss: 0.3543 - val_accuracy: 0.8571 - val_loss: 0.4424
# Epoch 40/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8864 - loss: 0.3349 - val_accuracy: 0.8571 - val_loss: 0.4377
# Epoch 41/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8449 - loss: 0.3810 - val_accuracy: 0.8730 - val_loss: 0.4439
# Epoch 42/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8864 - loss: 0.3334 - val_accuracy: 0.8571 - val_loss: 0.4431
# Epoch 43/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8775 - loss: 0.3407 - val_accuracy: 0.8571 - val_loss: 0.4345
# Epoch 44/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8637 - loss: 0.3621 - val_accuracy: 0.8730 - val_loss: 0.4376
# Epoch 45/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8642 - loss: 0.3589 - val_accuracy: 0.8730 - val_loss: 0.4201
# Epoch 46/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8582 - loss: 0.3800 - val_accuracy: 0.8730 - val_loss: 0.4553
# Epoch 47/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8889 - loss: 0.3381 - val_accuracy: 0.8730 - val_loss: 0.4246
# Epoch 48/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8538 - loss: 0.3698 - val_accuracy: 0.8571 - val_loss: 0.4310
# Epoch 49/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8812 - loss: 0.3342 - val_accuracy: 0.8571 - val_loss: 0.4287
# Epoch 50/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8681 - loss: 0.3452 - val_accuracy: 0.8571 - val_loss: 0.4248

# %%
history = history.history

plt.figure(figsize=(15, 5))


plt.subplot(121)
plt.title("Accuracy")
plt.plot(history["accuracy"], label="train acc")
plt.plot(history["val_accuracy"], label="val acc")
plt.legend()


plt.subplot(122)
plt.title("Loss")
plt.plot(history["loss"], label="train loss")
plt.plot(history["val_loss"], label="val loss")
plt.legend()

plt.show()

# %%
loss ,accuracy =model.evaluate(test_ds)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6765 - loss: 0.6244

# %%
print("test loss :",loss)
print("test accuracy:",accuracy)
# Out:
# test loss : 0.6938980221748352
# test accuracy: 0.682539701461792

# %%
print("Original")
display(df.head())

print("Predicted")
inference = df.head().drop("target", axis=1)

# Select only the relevant columns for inference
inference = inference[numerical_cols + numerical_categorical_cols + categorical_cols]

# Convert dataframe into dictionary format for TensorFlow model
inference_dict = {col: inference[col].values for col in inference.columns}

# Predict using the trained model
inference["target"] = model.predict(inference_dict)

# Display results
display(inference)
# Out:
# Original
#    target     sex   age  n_siblings_spouses  parch     fare  class     deck  \
# 0       0    male  22.0                   1      0   7.2500  Third  unknown
# 1       1  female  38.0                   1      0  71.2833  First        C
# 2       1  female  26.0                   0      0   7.9250  Third  unknown
# 3       1  female  35.0                   1      0  53.1000  First        C
# 4       0    male  28.0                   0      0   8.4583  Third  unknown
#
#    embark_town alone
# 0  Southampton     n
# 1    Cherbourg     n
# 2  Southampton     y
# 3  Southampton     n
# 4   Queenstown     y
# Predicted
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
#     age     fare  n_siblings_spouses  parch     sex  class     deck  \
# 0  22.0   7.2500                   1      0    male  Third  unknown
# 1  38.0  71.2833                   1      0  female  First        C
# 2  26.0   7.9250                   0      0  female  Third  unknown
# 3  35.0  53.1000                   1      0  female  First        C
# 4  28.0   8.4583                   0      0    male  Third  unknown
#
#    embark_town alone    target
# 0  Southampton     n  0.255393
# 1    Cherbourg     n  0.746517
# 2  Southampton     y  0.746517
# 3  Southampton     n  0.746517
# 4   Queenstown     y  0.063647
